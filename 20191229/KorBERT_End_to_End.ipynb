# %% [markdown]
# # KorBERT End to End
# Author: MyungHoon Jin

# %% [markdown]
# Import Library

# %%
import collections
import re
import unicodedata
import six
import csv
import os
import copy
import json
import math
import numpy as np
import pandas as pd
from eunjeon import Mecab
from konlpy.tag import Kkma, Okt
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Data Preparing
# 한국어 BERT를 실습하기 위해 준비해야할 사항들이 있다.
#
# 우선, pre-training BERT를 적용하기 위해 Dacon2019 금융문자 스미싱 데이터를 활용하여 이진분류 문제를 풀어보겠다.
#
# 데이터는 오른쪽 링크에서 얻을 수 있다. https://dacon.io/cpt14

# %%
data_path = './data/' # 각자의 data path를 입력하도록 하자.
df_train = pd.read_csv(data_path + 'train.csv')
df_test = pd.read_csv(data_path + 'public_test.csv')

# %%
df_train.head()
# Out:
#    id year_month                                               text  smishing
# 0   0    2017-01                           XXX은행성산XXX팀장입니다.행복한주말되세요         0
# 1   1    2017-01              오늘도많이웃으시는하루시작하세요XXX은행 진월동VIP라운지 XXX올림         0
# 2   2    2017-01  안녕하십니까 고객님. XXX은행입니다.금일 납부하셔야 할 금액은 153600원 입니...         0
# 3   4    2017-01  XXX 고객님안녕하세요XXX은행 XXX지점입니다지난 한 해 동안 저희 XXX지점에 ...         0
# 4   5    2017-01           1월은 새로움이 가득XXX입니다.올 한해 더 많이행복한 한해되시길바랍니다         0

# %%
df_test.head()
# Out:
#        id year_month                                               text
# 0  340000    2019-01  XXX고객님! 안녕하세요? 새롭게 시작하는 한 주 행복 가득하시길 기원합니다. 지난...
# 1  340001    2019-01   긴급 안내  XXX은행 가락동 지점  - 헬리오XXX 기본XXX    대출이자를 ...
# 2  340002    2019-01  XXX 고객님 안녕하세요올해는 미세먼지가 유난인거 같습니다.엊그제 새해가 시작된거같...
# 3  340003    2019-01  XXX 고객님찾아온 행운을 잡으셨나요? 못잡으셨다면 이번에 다시 잡으시길 기원합니다...
# 4  340004    2019-01  XXX 고객님새해 복 많이 받으세요 XXX은행 코스트코 퇴직연금 담당자입니다.  고...

# %% [markdown]
# BERT Input을 위해 가벼운(그러나 오래걸리는) 전처리를 실시해보도록 하자.

# %%
# spacing
from chatspace import ChatSpace

spacer = ChatSpace()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-5-6663df0e2cfb> in <module>
#       2 from chatspace import ChatSpace
#       3
# ----> 4 spacer = ChatSpace()
#
# ~\Anaconda3\envs\basic\lib\site-packages\chatspace\inference.py in __init__(self, model_path, config_path, vocab_path, device, from_jit)
#      39     ):
#      40         self.config = self._load_config(config_path)
# ---> 41         self.vocab = self._load_vocab(vocab_path)
#      42         self.device = torch.device(device)
#      43
#
# ~\Anaconda3\envs\basic\lib\site-packages\chatspace\inference.py in _load_vocab(self, vocab_path)
#     202         """
#     203         with open(vocab_path) as f:
# --> 204             vocab_tokens = [line.strip() for line in f]
#     205         vocab = Vocab(tokens=vocab_tokens)
#     206         self.config["vocab_size"] = len(vocab)
#
# ~\Anaconda3\envs\basic\lib\site-packages\chatspace\inference.py in <listcomp>(.0)
#     202         """
#     203         with open(vocab_path) as f:
# --> 204             vocab_tokens = [line.strip() for line in f]
#     205         vocab = Vocab(tokens=vocab_tokens)
#     206         self.config["vocab_size"] = len(vocab)
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xec in position 22: illegal multibyte sequence

# %% [markdown]
# 위와 같은 에러가 발생해도 당황하지 마라. (Linux, Mac을 이용하는 유저는 위의 에러가 뜨지 않을 것이다.)
#
# Window 유저만 해당하는 cp949문제이다.
#
# 기존 PINGPONG에서 제공하는 API에서는 해당 encoding에 접근할 parameter가 없기 때문에 이를 수정하여 사용하도록 하자.
#
# 우선, python shell에서 다음의 명령어를 입력하여 자신의 envs의 site-packages가 어디있는지 확인하라.

# %%
import site

site.getsitepackages()
# Out:
# ['C:\\Users\\jinma\\Anaconda3\\envs\\basic',
#  'C:\\Users\\jinma\\Anaconda3\\envs\\basic\\lib\\site-packages']

# %% [markdown]
# 다음으로, 해당 site-packages에서 chatspace/inference.py 파일에 들어가서 아래 사항들을 수정하라.
#
# ```python
# # first, revise function '_load_vocab' lines as follow; (line 196~207)
#     def _load_vocab(self, vocab_path: str, encoding: str) -> Vocab:
#         """
#         저장된 vocab 을 로딩
#
#         :param vocab_path: vocab 위치
#         :return: 로딩된 vocab
#         """
#         with open(vocab_path, encoding=encoding) as f:
#             vocab_tokens = [line.strip() for line in f]
#         vocab = Vocab(tokens=vocab_tokens)
#         self.config["vocab_size"] = len(vocab)
#         return vocab
#
# # And then, revise __init__ as follow; (line 31~50)
# class ChatSpace:
#     def __init__(
#         self,
#         model_path: str = None,
#         config_path: str = CONFIG_PATH,
#         vocab_path: str = VOCAB_PATH,
#         device: str = "cpu",
#         from_jit: bool = True,
#         encoding: str = 'utf-8',
#     ):
#         self.config = self._load_config(config_path)
#         self.vocab = self._load_vocab(vocab_path, encoding=encoding)
#         self.device = torch.device(device)
#
#         if model_path is None:
#             from_jit = self._is_jit_available() if from_jit else False
#             model_path = JIT_MODEL_PATH if from_jit else MODEL_DICT_PATH
#
#         self.model = self._load_model(model_path, self.device, from_jit=from_jit)
#         self.model.eval()
# ```

# %% [markdown]
# 그러면 완성☆ (jupyter notebook을 이용할 경우 kernel을 죽이고 재시동해야 된다.)

# %%
# spacing
from chatspace import ChatSpace

# If you want to use gpu on torch, set parameter name 'device' as 'cuda'.
spacer = ChatSpace(device='cuda')
# Out:
# Loading JIT Compiled ChatSpace Model

# %% [markdown]
# PINGPONG에서 제공하는 띄어쓰기 API를 적용해보자.

# %%
RESOURCE_PATH = 'C:/Users/jinma/Anaconda3/envs/basic/Lib/site-packages/chatspace'

VOCAB_PATH = os.path.join(RESOURCE_PATH, "vocab.txt")
MODEL_DICT_PATH = os.path.join(RESOURCE_PATH, "model/model.pt")
JIT_MODEL_PATH = os.path.join(RESOURCE_PATH, "model/model_jit.pt")
CONFIG_PATH = os.path.join(RESOURCE_PATH, "config.json")

# %%
spacer.config
# Out:
# {'learning_rate': 0.001,
#  'batch_size': 512,
#  'valid_ratio': 0.025,
#  'epochs': 15,
#  'vocab_min_freq': 3,
#  'min_seq_len': 7,
#  'num_workers': 0,
#  'logging_step': 500,
#  'validation_step': 1500,
#  'test_threshold': 0.5,
#  'use_multi_gpu': False,
#  'device': 'cuda',
#  'embedding_dim': 256,
#  'cnn_filter': 3,
#  'cnn_features': 128,
#  'space_prob': [0, 0.15, 0.4],
#  'lstm_bidirectional': True,
#  'dropout_keep_prob': 0.1,
#  'apply_weight': False,
#  'lstm_layers': 1,
#  'vocab_size': 3563}

# %%
spacer.vocab
# Out:
# {'[PAD]': 0,
#  '[UNK]': 1,
#  '[SOS]': 2,
#  '[EOS]': 3,
#  ' ': 4,
#  '<pad>': 5,
#  '<unk>': 6,
#  '<space>': 7,
#  '.': 8,
#  '이': 9,
#  '어': 10,
#  '아': 11,
#  '?': 12,
#  '다': 13,
#  '나': 14,
#  '가': 15,
#  '그': 16,
#  '요': 17,
#  'ㅋ': 18,
#  '고': 19,
#  '지': 20,
#  '는': 21,
#  '하': 22,
#  '니': 23,
#  '도': 24,
#  '응': 25,
#  'ㅎ': 26,
#  '자': 27,
#  '거': 28,
#  '해': 29,
#  '에': 30,
#  '야': 31,
#  '게': 32,
#  '서': 33,
#  '안': 34,
#  '오': 35,
#  '데': 36,
#  '기': 37,
#  'ㅠ': 38,
#  '내': 39,
#  '있': 40,
#  '리': 41,
#  '!': 42,
#  '시': 43,
#  '은': 44,
#  '사': 45,
#  '네': 46,
#  '한': 47,
#  '라': 48,
#  '일': 49,
#  '제': 50,
#  '래': 51,
#  '구': 52,
#  '면': 53,
#  '보': 54,
#  ',': 55,
#  '마': 56,
#  '잘': 57,
#  '을': 58,
#  '만': 59,
#  '너': 60,
#  '까': 61,
#  '먹': 62,
#  '뭐': 63,
#  '말': 64,
#  '왜': 65,
#  '난': 66,
#  '들': 67,
#  '로': 68,
#  '무': 69,
#  '으': 70,
#  '웅': 71,
#  '여': 72,
#  '저': 73,
#  '좀': 74,
#  '우': 75,
#  '금': 76,
#  '수': 77,
#  '대': 78,
#  '없': 79,
#  '좋': 80,
#  '겠': 81,
#  '주': 82,
#  '진': 83,
#  '러': 84,
#  '와': 85,
#  '더': 86,
#  '했': 87,
#  '할': 88,
#  '정': 89,
#  '같': 90,
#  '알': 91,
#  '집': 92,
#  '려': 93,
#  '음': 94,
#  '전': 95,
#  '인': 96,
#  '럼': 97,
#  '었': 98,
#  'N': 99,
#  '장': 100,
#  '근': 101,
#  '늘': 102,
#  '부': 103,
#  '세': 104,
#  '히': 105,
#  '생': 106,
#  '봐': 107,
#  '냐': 108,
#  '님': 109,
#  '건': 110,
#  '미': 111,
#  '많': 112,
#  '랑': 113,
#  '신': 114,
#  '~': 115,
#  '왔': 116,
#  '못': 117,
#  '되': 118,
#  '짜': 119,
#  '간': 120,
#  '때': 121,
#  '바': 122,
#  '예': 123,
#  '모': 124,
#  '두': 125,
#  '빠': 126,
#  '냥': 127,
#  '의': 128,
#  '런': 129,
#  '비': 130,
#  '렇': 131,
#  '상': 132,
#  '았': 133,
#  '엄': 134,
#  '또': 135,
#  '를': 136,
#  '씨': 137,
#  '것': 138,
#  '갈': 139,
#  '밥': 140,
#  '습': 141,
#  '워': 142,
#  '화': 143,
#  '버': 144,
#  '원': 145,
#  '날': 146,
#  '치': 147,
#  '직': 148,
#  '중': 149,
#  '심': 150,
#  '람': 151,
#  '돼': 152,
#  '머': 153,
#  '애': 154,
#  '스': 155,
#  '소': 156,
#  '드': 157,
#  '당': 158,
#  '디': 159,
#  '방': 160,
#  '죠': 161,
#  '테': 162,
#  '누': 163,
#  '실': 164,
#  '끝': 165,
#  '얼': 166,
#  '잠': 167,
#  '조': 168,
#  '분': 169,
#  '번': 170,
#  '싶': 171,
#  '차': 172,
#  '동': 173,
#  '연': 174,
#  '선': 175,
#  '걸': 176,
#  '맞': 177,
#  '잖': 178,
#  '살': 179,
#  '남': 180,
#  '영': 181,
#  '언': 182,
#  '각': 183,
#  '른': 184,
#  '줄': 185,
#  '배': 186,
#  '입': 187,
#  '올': 188,
#  '단': 189,
#  '헤': 190,
#  '르': 191,
#  '혼': 192,
#  '문': 193,
#  '든': 194,
#  '호': 195,
#  '슨': 196,
#  '회': 197,
#  '속': 198,
#  '계': 199,
#  '식': 200,
#  '재': 201,
#  '않': 202,
#  '피': 203,
#  '물': 204,
#  '긴': 205,
#  '줘': 206,
#  '유': 207,
#  '따': 208,
#  '빨': 209,
#  '몰': 210,
#  '-': 211,
#  '준': 212,
#  '파': 213,
#  '괜': 214,
#  '얘': 215,
#  '찮': 216,
#  '운': 217,
#  '감': 218,
#  '막': 219,
#  '공': 220,
#  '울': 221,
#  '헐': 222,
#  '친': 223,
#  '받': 224,
#  '개': 225,
#  '씻': 226,
#  '쉬': 227,
#  '청': 228,
#  '타': 229,
#  '발': 230,
#  '강': 231,
#  '터': 232,
#  '갔': 233,
#  '학': 234,
#  '힘': 235,
#  '났': 236,
#  '떻': 237,
#  '노': 238,
#  '셨': 239,
#  '약': 240,
#  '형': 241,
#  '착': 242,
#  '싫': 243,
#  '맛': 244,
#  '던': 245,
#  '반': 246,
#  '경': 247,
#  '죽': 248,
#  '찍': 249,
#  '됐': 250,
#  '써': 251,
#  '참': 252,
#  '술': 253,
#  '과': 254,
#  '눈': 255,
#  '불': 256,
#  '용': 257,
#  'ㅇ': 258,
#  '볼': 259,
#  '교': 260,
#  '늦': 261,
#  '결': 262,
#  '달': 263,
#  '출': 264,
#  '행': 265,
#  '후': 266,
#  '국': 267,
#  '열': 268,
#  '넌': 269,
#  '잉': 270,
#  '쪽': 271,
#  '졸': 272,
#  '놀': 273,
#  '길': 274,
#  '겨': 275,
#  '넘': 276,
#  '성': 277,
#  '민': 278,
#  '잤': 279,
#  '넹': 280,
#  '새': 281,
#  '돈': 282,
#  '봤': 283,
#  '처': 284,
#  '적': 285,
#  '점': 286,
#  '별': 287,
#  '작': 288,
#  '께': 289,
#  '온': 290,
#  '위': 291,
#  '뭘': 292,
#  '낼': 293,
#  '져': 294,
#  '임': 295,
#  '군': 296,
#  '귀': 297,
#  '키': 298,
#  '허': 299,
#  '프': 300,
#  '곧': 301,
#  '천': 302,
#  '루': 303,
#  '힝': 304,
#  '명': 305,
#  '손': 306,
#  '뭔': 307,
#  '편': 308,
#  '셔': 309,
#  '♥': 310,
#  '김': 311,
#  '트': 312,
#  '합': 313,
#  '꼭': 314,
#  '듯': 315,
#  '산': 316,
#  '업': 317,
#  '완': 318,
#  '질': 319,
#  '린': 320,
#  '락': 321,
#  '쓰': 322,
#  '양': 323,
#  '꺼': 324,
#  '…': 325,
#  '관': 326,
#  'ㅡ': 327,
#  '깐': 328,
#  '>': 329,
#  '느': 330,
#  '함': 331,
#  '<': 332,
#  '앞': 333,
#  '벌': 334,
#  '박': 335,
#  '십': 336,
#  '추': 337,
#  '앙': 338,
#  '본': 339,
#  '현': 340,
#  '태': 341,
#  '먼': 342,
#  '잔': 343,
#  '설': 344,
#  '찾': 345,
#  '통': 346,
#  '매': 347,
#  '병': 348,
#  '잡': 349,
#  '월': 350,
#  '엉': 351,
#  '녀': 352,
#  '침': 353,
#  '담': 354,
#  '된': 355,
#  '딱': 356,
#  '랬': 357,
#  '휴': 358,
#  '^': 359,
#  '돌': 360,
#  '글': 361,
#  '꾸': 362,
#  '크': 363,
#  '싸': 364,
#  '카': 365,
#  '둘': 366,
#  '몇': 367,
#  '희': 368,
#  '쁘': 369,
#  '릴': 370,
#  '놈': 371,
#  '복': 372,
#  'M': 373,
#  '목': 374,
#  '렸': 375,
#  '역': 376,
#  '년': 377,
#  '녁': 378,
#  '럴': 379,
#  '될': 380,
#  '체': 381,
#  '닌': 382,
#  '절': 383,
#  '갑': 384,
#  '답': 385,
#  '밖': 386,
#  '밤': 387,
#  '겁': 388,
#  '흐': 389,
#  '송': 390,
#  '놓': 391,
#  '름': 392,
#  '망': 393,
#  '엔': 394,
#  '퇴': 395,
#  '쳐': 396,
#  '굴': 397,
#  '녕': 398,
#  '떡': 399,
#  '곤': 400,
#  '옷': 401,
#  '몸': 402,
#  '맘': 403,
#  '티': 404,
#  '웃': 405,
#  '란': 406,
#  '케': 407,
#  'ㄱ': 408,
#  '끼': 409,
#  '백': 410,
#  '걱': 411,
#  '푹': 412,
#  '며': 413,
#  '슬': 414,
#  '커': 415,
#  '걍': 416,
#  '변': 417,
#  '필': 418,
#  '톡': 419,
#  '증': 420,
#  '석': 421,
#  '철': 422,
#  '삼': 423,
#  '레': 424,
#  '코': 425,
#  '뻐': 426,
#  '쁜': 427,
#  '맨': 428,
#  'ㄷ': 429,
#  '깨': 430,
#  '짐': 431,
#  '졌': 432,
#  '순': 433,
#  '책': 434,
#  '짱': 435,
#  '죄': 436,
#  '흥': 437,
#  '억': 438,
#  '표': 439,
#  '듣': 440,
#  '였': 441,
#  '떠': 442,
#  '흠': 443,
#  '림': 444,
#  '외': 445,
#  '혀': 446,
#  '씀': 447,
#  '옹': 448,
#  'U': 449,
#  '칠': 450,
#  '초': 451,
#  '짓': 452,
#  '토': 453,
#  '확': 454,
#  '❤': 455,
#  '종': 456,
#  '포': 457,
#  '취': 458,
#  '즘': 459,
#  '큰': 460,
#  '폰': 461,
#  '팔': 462,
#  '쯤': 463,
#  ')': 464,
#  '챙': 465,
#  '급': 466,
#  '앉': 467,
#  '엥': 468,
#  '멀': 469,
#  '검': 470,
#  '믿': 471,
#  '험': 472,
#  '최': 473,
#  '꿈': 474,
#  '풀': 475,
#  '뽀': 476,
#  '충': 477,
#  '텐': 478,
#  '켜': 479,
#  'ㄴ': 480,
#  '혹': 481,
#  '뒤': 482,
#  '봉': 483,
#  '탔': 484,
#  '빼': 485,
#  '왕': 486,
#  '옴': 487,
#  '력': 488,
#  '움': 489,
#  '꼬': 490,
#  '쳤': 491,
#  '웠': 492,
#  '탁': 493,
#  '럽': 494,
#  '항': 495,
#  '놔': 496,
#  '춥': 497,
#  '빵': 498,
#  '윤': 499,
#  '굿': 500,
#  '헉': 501,
#  '찬': 502,
#  '암': 503,
#  '악': 504,
#  '평': 505,
#  '메': 506,
#  '쩌': 507,
#  '등': 508,
#  '떤': 509,
#  '독': 510,
#  '황': 511,
#  '옆': 512,
#  '법': 513,
#  '찌': 514,
#  '밀': 515,
#  '떨': 516,
#  '튼': 517,
#  '격': 518,
#  '접': 519,
#  '똑': 520,
#  '색': 521,
#  '궁': 522,
#  '투': 523,
#  '료': 524,
#  '갖': 525,
#  '째': 526,
#  '숙': 527,
#  '승': 528,
#  '숨': 529,
#  '밌': 530,
#  '넵': 531,
#  '붙': 532,
#  '널': 533,
#  '섭': 534,
#  '겼': 535,
#  '혜': 536,
#  '팅': 537,
#  '랐': 538,
#  '뇨': 539,
#  '젠': 540,
#  '골': 541,
#  '줌': 542,
#  '덥': 543,
#  '(': 544,
#  '판': 545,
#  '흑': 546,
#  '딸': 547,
#  '퍼': 548,
#  '쎄': 549,
#  '쓸': 550,
#  '론': 551,
#  '왱': 552,
#  '환': 553,
#  '택': 554,
#  '짝': 555,
#  '욕': 556,
#  '걔': 557,
#  '록': 558,
#  '능': 559,
#  '1': 560,
#  '뜻': 561,
#  '쩔': 562,
#  '봄': 563,
#  '앗': 564,
#  '끄': 565,
#  '틀': 566,
#  '맙': 567,
#  '곳': 568,
#  '창': 569,
#  'E': 570,
#  '족': 571,
#  '페': 572,
#  '땡': 573,
#  '줬': 574,
#  '헿': 575,
#  '0': 576,
#  '멋': 577,
#  '육': 578,
#  '축': 579,
#  '딴': 580,
#  '쫌': 581,
#  '땐': 582,
#  '읽': 583,
#  ';': 584,
#  '냈': 585,
#  '홍': 586,
#  '끊': 587,
#  '척': 588,
#  '넣': 589,
#  '큼': 590,
#  '플': 591,
#  '채': 592,
#  '범': 593,
#  '덕': 594,
#  '맥': 595,
#  '픈': 596,
#  'O': 597,
#  '엽': 598,
#  '끔': 599,
#  '뜨': 600,
#  '낮': 601,
#  '탈': 602,
#  '존': 603,
#  '젤': 604,
#  '빈': 605,
#  '깼': 606,
#  '품': 607,
#  ':': 608,
#  '킨': 609,
#  '닙': 610,
#  '쇼': 611,
#  '징': 612,
#  '특': 613,
#  '팀': 614,
#  '웬': 615,
#  '패': 616,
#  '쉽': 617,
#  '씩': 618,
#  '꿀': 619,
#  '멍': 620,
#  '풍': 621,
#  '찰': 622,
#  '덜': 623,
#  '베': 624,
#  '촌': 625,
#  '낫': 626,
#  '솔': 627,
#  '샀': 628,
#  '옥': 629,
#  '향': 630,
#  '즈': 631,
#  '왠': 632,
#  '2': 633,
#  '꿔': 634,
#  '얌': 635,
#  '섯': 636,
#  '랭': 637,
#  '랜': 638,
#  '낭': 639,
#  '잊': 640,
#  '닥': 641,
#  'ㅂ': 642,
#  '됨': 643,
#  '낌': 644,
#  '꽃': 645,
#  '뻔': 646,
#  '벽': 647,
#  '냄': 648,
#  '훈': 649,
#  '탕': 650,
#  '잇': 651,
#  '쟤': 652,
#  '둬': 653,
#  '뿐': 654,
#  '첫': 655,
#  '광': 656,
#  '콜': 657,
#  '딨': 658,
#  '견': 659,
#  '쟈': 660,
#  '브': 661,
#  '빡': 662,
#  '핸': 663,
#  '닝': 664,
#  '류': 665,
#  '퓨': 666,
#  '립': 667,
#  '빤': 668,
#  '냠': 669,
#  '똥': 670,
#  '3': 671,
#  '탄': 672,
#  '빌': 673,
#  '북': 674,
#  '씬': 675,
#  '맡': 676,
#  '삐': 677,
#  '딜': 678,
#  '꼴': 679,
#  '욱': 680,
#  '쿠': 681,
#  '낸': 682,
#  '뛰': 683,
#  '넴': 684,
#  '권': 685,
#  '효': 686,
#  '총': 687,
#  '뉴': 688,
#  '춰': 689,
#  '련': 690,
#  '썼': 691,
#  '샤': 692,
#  '령': 693,
#  '껴': 694,
#  '닐': 695,
#  '쪼': 696,
#  '놨': 697,
#  '땅': 698,
#  '/': 699,
#  '규': 700,
#  '쪄': 701,
#  '딩': 702,
#  '뀨': 703,
#  '곱': 704,
#  '슴': 705,
#  '묻': 706,
#  '꽤': 707,
#  '염': 708,
#  '뿌': 709,
#  '끌': 710,
#  '컴': 711,
#  '즐': 712,
#  '굳': 713,
#  '션': 714,
#  '닮': 715,
#  '깔': 716,
#  '롱': 717,
#  '깜': 718,
#  '냉': 719,
#  '쌍': 720,
#  '농': 721,
#  '잼': 722,
#  'ㅗ': 723,
#  '극': 724,
#  '5': 725,
#  '익': 726,
#  '닭': 727,
#  '둥': 728,
#  '핑': 729,
#  '활': 730,
#  '밑': 731,
#  '쩐': 732,
#  '텔': 733,
#  '융': 734,
#  '홀': 735,
#  '첨': 736,
#  '쉴': 737,
#  '블': 738,
#  'ㅅ': 739,
#  'o': 740,
#  '헛': 741,
#  '획': 742,
#  '됩': 743,
#  '욜': 744,
#  '압': 745,
#  '땀': 746,
#  '푸': 747,
#  '논': 748,
#  '쏘': 749,
#  '클': 750,
#  '폭': 751,
#  '례': 752,
#  '뽑': 753,
#  'e': 754,
#  '칼': 755,
#  '낳': 756,
#  '땜': 757,
#  '협': 758,
#  '뿅': 759,
#  '득': 760,
#  '슈': 761,
#  '렀': 762,
#  '딘': 763,
#  'ㅤ': 764,
#  '렵': 765,
#  '콩': 766,
#  '층': 767,
#  '렁': 768,
#  '쓴': 769,
#  '떼': 770,
#  '곡': 771,
#  '롭': 772,
#  '센': 773,
#  '셋': 774,
#  '옛': 775,
#  '믄': 776,
#  '콘': 777,
#  '쥐': 778,
#  '칭': 779,
#  '링': 780,
#  '껄': 781,
#  '💕': 782,
#  '낙': 783,
#  '짧': 784,
#  '헷': 785,
#  '쌀': 786,
#  '꺄': 787,
#  '캐': 788,
#  '싼': 789,
#  '댁': 790,
#  '탐': 791,
#  '릇': 792,
#  'a': 793,
#  '벗': 794,
#  '켰': 795,
#  '쭉': 796,
#  '흘': 797,
#  '흔': 798,
#  '몬': 799,
#  '쌤': 800,
#  '괴': 801,
#  '힣': 802,
#  '털': 803,
#  '쭈': 804,
#  '쟁': 805,
#  '뜩': 806,
#  '잃': 807,
#  '힌': 808,
#  '엘': 809,
#  '_': 810,
#  '춘': 811,
#  '끓': 812,
#  '덩': 813,
#  '랄': 814,
#  '녹': 815,
#  '볶': 816,
#  '컨': 817,
#  '짤': 818,
#  '값': 819,
#  '밝': 820,
#  '높': 821,
#  '쫓': 822,
#  '량': 823,
#  '훨': 824,
#  's': 825,
#  '쥬': 826,
#  '닦': 827,
#  '밍': 828,
#  '넷': 829,
#  '납': 830,
#  '큐': 831,
#  '엇': 832,
#  '4': 833,
#  't': 834,
#  '쿤': 835,
#  '킬': 836,
#  '쿨': 837,
#  '힐': 838,
#  '꿨': 839,
#  '쳇': 840,
#  '샘': 841,
#  '찜': 842,
#  '깝': 843,
#  '닫': 844,
#  '묵': 845,
#  '쨌': 846,
#  '캬': 847,
#  '걷': 848,
#  '헌': 849,
#  '옮': 850,
#  '댜': 851,
#  '댕': 852,
#  'ㅁ': 853,
#  '쩡': 854,
#  '뎅': 855,
#  '혁': 856,
#  '둔': 857,
#  '뒷': 858,
#  '헝': 859,
#  '슷': 860,
#  '혈': 861,
#  '몽': 862,
#  '얻': 863,
#  '늙': 864,
#  '놉': 865,
#  '젊': 866,
#  '짠': 867,
#  '녜': 868,
#  '햄': 869,
#  '얍': 870,
#  'n': 871,
#  '쉐': 872,
#  '갚': 873,
#  '액': 874,
#  '윽': 875,
#  'A': 876,
#  '껀': 877,
#  '칫': 878,
#  '팩': 879,
#  '빙': 880,
#  '겹': 881,
#  '싹': 882,
#  '뺏': 883,
#  '렴': 884,
#  'i': 885,
#  '띠': 886,
#  '빛': 887,
#  '뷰': 888,
#  '봅': 889,
#  '뵙': 890,
#  '끗': 891,
#  '뚝': 892,
#  '뚜': 893,
#  '뻥': 894,
#  '훗': 895,
#  '홉': 896,
#  '턴': 897,
#  '렌': 898,
#  '겜': 899,
#  '롤': 900,
#  '힛': 901,
#  '훔': 902,
#  '꾼': 903,
#  '갸': 904,
#  '덮': 905,
#  '팬': 906,
#  '쁨': 907,
#  'ㅈ': 908,
#  '곰': 909,
#  '튀': 910,
#  '춤': 911,
#  '랴': 912,
#  '촬': 913,
#  '쵸': 914,
#  '싱': 915,
#  '뽕': 916,
#  '뵈': 917,
#  '햇': 918,
#  '끈': 919,
#  '맹': 920,
#  '껏': 921,
#  '욧': 922,
#  '럭': 923,
#  '긍': 924,
#  '붕': 925,
#  '혔': 926,
#  '핫': 927,
#  '듬': 928,
#  '멘': 929,
#  '념': 930,
#  '객': 931,
#  '뚱': 932,
#  '쩜': 933,
#  '9': 934,
#  '멈': 935,
#  '펴': 936,
#  '헬': 937,
#  'd': 938,
#  '썩': 939,
#  '룹': 940,
#  '랍': 941,
#  '빴': 942,
#  '탓': 943,
#  '겸': 944,
#  '슝': 945,
#  '댔': 946,
#  'h': 947,
#  '폐': 948,
#  '앤': 949,
#  '깡': 950,
#  '흉': 951,
#  '셈': 952,
#  '츠': 953,
#  '굶': 954,
#  '6': 955,
#  '룸': 956,
#  '댓': 957,
#  '눌': 958,
#  '벼': 959,
#  '깊': 960,
#  '꽉': 961,
#  '셤': 962,
#  '‘': 963,
#  '씹': 964,
#  '팍': 965,
#  '7': 966,
#  '’': 967,
#  '댄': 968,
#  '킹': 969,
#  '😊': 970,
#  '델': 971,
#  '덟': 972,
#  '픔': 973,
#  '뒀': 974,
#  '찔': 975,
#  '쌩': 976,
#  '쁠': 977,
#  '쌈': 978,
#  '탱': 979,
#  '웡': 980,
#  '8': 981,
#  'r': 982,
#  '율': 983,
#  '릿': 984,
#  '꽁': 985,
#  '좌': 986,
#  '쩍': 987,
#  '갠': 988,
#  '넓': 989,
#  '쪙': 990,
#  'u': 991,
#  '핵': 992,
#  '틈': 993,
#  '컷': 994,
#  '흰': 995,
#  '꼼': 996,
#  '왓': 997,
#  '턱': 998,
#  '짬': 999,
#  ...}

# %%
import sys
sys.path.append(RESOURCE_PATH)
sys.path.append(RESOURCE_PATH + '/data')
sys.path.append(RESOURCE_PATH + '/data/corpus')
sys.path.append(RESOURCE_PATH + '/data/indexer')
sys.path.append(RESOURCE_PATH + '/data/vocab')

# %%
from corpus import DynamicCorpus
from indexer import Indexer
from vocab import Vocab
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-58-11f64d9a2542> in <module>
#       1 from corpus import DynamicCorpus
# ----> 2 from indexer import Indexer
#       3 from vocab import Vocab
#
# C:/Users/jinma/Anaconda3/envs/basic/Lib/site-packages/chatspace/data\indexer.py in <module>
#      17 from typing import Iterable, List, Optional, Union
#      18
# ---> 19 from .vocab import Vocab
#      20
#      21
#
# ImportError: attempted relative import with no known parent package

# %%
from dataset import ChatSpaceDataset
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-53-25e889ae0403> in <module>
# ----> 1 from dataset import ChatSpaceDataset
#
# C:/Users/jinma/Anaconda3/envs/basic/Lib/site-packages/chatspace/data\dataset.py in <module>
#      21 from torch.utils.data import Dataset
#      22
# ---> 23 from .corpus import DynamicCorpus
#      24 from .indexer import Indexer
#      25 from .vocab import Vocab
#
# ImportError: attempted relative import with no known parent package

# %%
text = texts.iloc[0]

# %%
if isinstance(text, str):
    batch_texts = [text]

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.get_device_name(0)
# Out:
# 'GeForce RTX 2060'

# %%
for batch_texts
# Out:
# ['XXX은행성산XXX팀장입니다.행복한주말되세요']

# %%
# train과 test length 기록
len_train, len_test = len(df_train), len(df_test)

# train과 test의 text를 concatenate
texts = pd.concat((df_train.text, df_test.text))

# Spacing
# %time texts = list(map(lambda x: spacer.space(x), texts.values))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <timed exec> in <module>
#
# <timed exec> in <lambda>(x)
#
# ~\Anaconda3\envs\basic\lib\site-packages\chatspace\inference.py in space(self, texts, batch_size)
#      62
#      63         batch_texts = [texts] if isinstance(texts, str) else texts
# ---> 64         outputs = [output_text for output_text in self.space_iter(batch_texts, batch_size)]
#      65         return outputs if len(outputs) > 1 else outputs[0]
#      66
#
# ~\Anaconda3\envs\basic\lib\site-packages\chatspace\inference.py in <listcomp>(.0)
#      62
#      63         batch_texts = [texts] if isinstance(texts, str) else texts
# ---> 64         outputs = [output_text for output_text in self.space_iter(batch_texts, batch_size)]
#      65         return outputs if len(outputs) > 1 else outputs[0]
#      66
#
# ~\Anaconda3\envs\basic\lib\site-packages\chatspace\inference.py in space_iter(self, texts, batch_size)
#      84         for i, batch in enumerate(data_loader):
#      85             batch_texts = texts[i * batch_size : i * batch_size + batch_size]
# ---> 86             for text in self._single_batch_inference(batch=batch, batch_texts=batch_texts):
#      87                 yield text
#      88
#
# ~\Anaconda3\envs\basic\lib\site-packages\chatspace\inference.py in _single_batch_inference(self, batch, batch_texts)
#     104         """
#     105         # model forward for chat-space nn.Module
# --> 106         output = self.model.forward(batch["input"], batch["length"])
#     107
#     108         # make probability into class index with argmax
#
# RuntimeError: Expected object of backend CUDA but got backend CPU for argument #3 'index'
# The above operation failed in interpreter, with the following stack trace:
# at code/model_jit.py:43:17
#   bias1 = _22.bias
#   _23 = self.batch_normalization
#   weight3 = _23.weight
#   bias2 = _23.bias
#   running_mean = _23.running_mean
#   running_var = _23.running_var
#   _24 = self.layer_normalization
#   weight4 = _24.weight
#   bias3 = _24.bias
#   embed_input = torch.embedding(weight, input, -1, False, False)
#                 ~~~~~~~~~~~~~~~ <--- HERE
#   input0 = torch.transpose(embed_input, 1, 2)
#   input1 = torch._convolution(input0, _2, _3, [1], [0], [1], False, [0], 1, False, False, True)
#   input2 = torch.constant_pad_nd(input1, [1, 1], 0)
#   input3 = torch._convolution(input2, _5, _6, [1], [0], [1], False, [0], 1, False, False, True)
#   conv2_paded = torch.constant_pad_nd(input3, [3, 3], 0)
#   input4 = torch.cat([input2, conv2_paded], 1)
#   input5 = torch._convolution(input4, _8, _9, [1], [0], [1], False, [0], 1, False, False, True)
#   conv3_paded1 = torch.constant_pad_nd(input5, [2, 2], 0)
#   input6 = torch._convolution(input0, _8, _9, [1], [0], [1], False, [0], 1, False, False, True)
# The above operation failed in interpreter, with the following stack trace:
